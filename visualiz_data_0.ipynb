# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\PC\Downloads\genome_matrix.csv").set_index("Unnamed: 0")
df.head()
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df, cmap = "viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'species0'}>,
#         <Axes: title={'center': 'species1'}>],
#        [<Axes: title={'center': 'species2'}>,
#         <Axes: title={'center': 'species3'}>],
#        [<Axes: title={'center': 'species4'}>, <Axes: >]], dtype=object)
